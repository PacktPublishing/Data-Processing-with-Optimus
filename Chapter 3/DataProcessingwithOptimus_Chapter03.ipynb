# %% [markdown]
# # Chapter Three- Data Processing with Optimus

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../Optimus")

# %%
from optimus import Optimus 
op = Optimus("dask") 
op.engine
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\argenisleon\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
# 'dask'

# %%
df = op.load.csv("foo.csv")

# %% [markdown]
# ## Datatypes

# %% [markdown]
# ### Data conversion

# %%
df = op.load.csv("foo.csv")

# %%
df
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# name        job                id  birth
# (object)    (object)      (int64)  (object)
# ----------  ----------  ---------  ----------
# optimus     Leader              1  22/10/10
# bumblebee   Espionage           2  22/08/08
# eject       1                   3  23/07/10
# 2           3                   4  22/10/10

# %%
print(df.cols.to_integer("name"))
# Out:
#      name  job                id  birth
#   (int64)  (object)      (int64)  (object)
# ---------  ----------  ---------  ----------
#         0  Leader              1  22/10/10
#         0  Espionage           2  22/08/08
#         0  1                   3  23/07/10
#         2  3                   4  22/10/10
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:3370: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('name', 'int64'))
#
#   warnings.warn(meta_warning(meta))
# ...

# %%
print(df.cols.to_float("name"))
# Out:
#        name  job                id  birth
#   (float64)  (object)      (int64)  (object)
# -----------  ----------  ---------  ----------
#         nan  Leader              1  22/10/10
#         nan  Espionage           2  22/08/08
#         nan  1                   3  23/07/10
#           2  3                   4  22/10/10
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:3370: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('name', 'float64'))
#
#   warnings.warn(meta_warning(meta))
# ...

# %%
print(df.cols.to_string("id"))
# Out:
# name        job                 id  birth
# (object)    (object)      (object)  (object)
# ----------  ----------  ----------  ----------
# optimus     Leader               1  22/10/10
# bumblebee   Espionage            2  22/08/08
# eject       1                    3  23/07/10
# 2           3                    4  22/10/10
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))

# %%
import pandas as pd
pd.to_datetime('22/10/10', format='%y/%m/%d', errors='coerce')
# Out:
# Timestamp('2022-10-10 00:00:00')

# %%
print(df.cols.to_datetime("birth", '%y/%m/%d'))
# Out:
# name        job                id  birth
# (object)    (object)      (int64)  (datetime64[ns])
# ----------  ----------  ---------  -------------------
# optimus     Leader              1  2022-10-10 00:00:00
# bumblebee   Espionage           2  2022-08-08 00:00:00
# eject       1                   3  2023-07-10 00:00:00
# 2           3                   4  2022-10-10 00:00:00
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))

# %% [markdown]
# ### Optimization

# %%
# df.optimize()
# data = {"name":[0, 1,2,3,4,5]}

# %%
df.cols.names()
# Out:
# ['name', 'job', 'id', 'birth']

# %%
df.cols.select("job").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'job\n(object)\n----------\nLeader\nEspionage\n1\n3'

# %%
df.cols.select(["name","job"]).ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name        job\n(object)    (object)\n----------  ----------\noptimus     Leader\nbumblebee   Espionage\neject       1\n2           3'

# %%
df.cols.select("job",invert=True).ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name               id  birth\n(object)      (int64)  (object)\n----------  ---------  ----------\noptimus             1  22/10/10\nbumblebee           2  22/08/08\neject               3  23/07/10\n2                   4  22/10/10'

# %%
df.cols.select(regex="^n.").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name\n(object)\n----------\noptimus\nbumblebee\neject\n2'

# %%
df.cols.select("id").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# '       id\n  (int64)\n---------\n        1\n        2\n        3\n        4'

# %%
print(df.cols.select(data_type="int", ))
# Out:
# name        job                id  birth
# (object)    (object)      (int64)  (object)
# ----------  ----------  ---------  ----------
# optimus     Leader              1  22/10/10
# bumblebee   Espionage           2  22/08/08
# eject       1                   3  23/07/10
# 2           3                   4  22/10/10
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))

# %%
df.cols.upper("name").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name        job                id  birth\n(object)    (object)      (int64)  (object)\n----------  ----------  ---------  ----------\nOPTIMUS     Leader              1  22/10/10\nBUMBLEBEE   Espionage           2  22/08/08\nEJECT       1                   3  23/07/10\n2           3                   4  22/10/10'

# %%
df.cols.upper("name","upper_name").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name        upper_name    job                id  birth\n(object)    (object)      (object)      (int64)  (object)\n----------  ------------  ----------  ---------  ----------\noptimus     OPTIMUS       Leader              1  22/10/10\nbumblebee   BUMBLEBEE     Espionage           2  22/08/08\neject       EJECT         1                   3  23/07/10\n2           2             3                   4  22/10/10'

# %%
df.cols.upper(["name","job"],"suffix").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name        name_suffix    job         job_suffix           id  birth\n(object)    (object)       (object)    (object)        (int64)  (object)\n----------  -------------  ----------  ------------  ---------  ----------\noptimus     OPTIMUS        Leader      LEADER                1  22/10/10\nbumblebee   BUMBLEBEE      Espionage   ESPIONAGE             2  22/08/08\neject       EJECT          1           1                     3  23/07/10\n2           2              3           3                     4  22/10/10'

# %%
df.cols.upper("*").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name        job                 id  birth\n(object)    (object)      (object)  (object)\n----------  ----------  ----------  ----------\nOPTIMUS     LEADER               1  22/10/10\nBUMBLEBEE   ESPIONAGE            2  22/08/08\nEJECT       1                    3  23/07/10\n2           3                    4  22/10/10'

# %%
df.cols.upper("name").cols.lower("job").ascii()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6383: UserWarning: Insufficient elements for `head`. 10 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# 'name        job                id  birth\n(object)    (object)      (int64)  (object)\n----------  ----------  ---------  ----------\nOPTIMUS     leader              1  22/10/10\nBUMBLEBEE   espionage           2  22/08/08\nEJECT       1                   3  23/07/10\n2           3                   4  22/10/10'

# %% [markdown]
# ## Date and time Functions

# %% [markdown]
# ## URL Functions

# %%
from optimus import Optimus
op = Optimus("pandas") 

data = {"A":["https://www.hi-optimus.com:8080/index.php?a=1"]} 
df = op.create.dataframe(data)

df["port"]= df.cols.port("A")
df["subdomain"]= df.cols.subdomain("A")
df["domain"]= df.cols.domain("A")

# %%
df = op.create.dataframe({    "values": [0.5, "2", 3.14],    "dummy": ["foo", "bar", "baz"]}) 

df.ascii()
# Out:
#     values  dummy
#   (object)  (object)
# ----------  ----------
#       0.5   foo
#       2     bar
#       3.14  baz

# %%
df.cols.sin("values").ascii()
# Out:
#      values  dummy
#   (float64)  (object)
# -----------  ----------
#  0.479426    foo
#  0.909297    bar
#  0.00159265  baz

# %%
df.cols.log("values", 5).ascii()
# Out:
#      values  dummy
#   (float64)  (object)
# -----------  ----------
#   -0.430677  foo
#    0.430677  bar
#    0.710946  baz

# %% [markdown]
# ## Email functions

# %%
from optimus import Optimus
op = Optimus("pandas") 

data = {"A":["argenis@gmail.com"]} 
df = op.create.dataframe(data)

df["username"]= df.cols.email_username("A")
df["domain"]= df.cols.email_domain("A")

# %% [markdown]
# ### UDF

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../../Optimus")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from optimus import Optimus
op = Optimus("pandas")

# %%
data = {"A":[0, 1,2,3,4,5],"B":[6,7,8,9,10,11]} 
df = op.create.dataframe(data)

# %%
df
# Out:
#         A          B
#   (int64)    (int64)
# ---------  ---------
#         0          6
#         1          7
#         2          8
#         3          9
#         4         10
#         5         11

# %%
def udf(value):    
    print(type(value))
    return value + 2

print(df.cols.apply("A",udf))
# Out:
# <class 'pandas.core.series.Series'>
#         A          B
#   (int64)    (int64)
# ---------  ---------
#         2          6
#         3          7
#         4          8
#         5          9
#         6         10
#         7         11

# %%
def udf(value):    
    print(value)
#     print(type(value))
    return value

df.cols.apply("B",udf, mode="map")
# Out:
# 6
# 7
# 8
# 9
# 10
# 11
#         A          B
#   (int64)    (int64)
# ---------  ---------
#         0          6
#         1          7
#         2          8
#         3          9
#         4         10
#         5         11

# %%
def udf(value):    
    return value + 2

print(df.cols.apply("*",udf))
# Out:
#         A          B
#   (int64)    (int64)
# ---------  ---------
#         2          8
#         3          9
#         4         10
#         5         11
#         6         12
#         7         13

# %%
op = Optimus("pandas")
df =op.load.file("DCIGNP2AYL.txt")

# %%
df
# Out:
#   ean_hotel_id  name                                     address1                 city        state_province      postal_code     latitude    longitude    star_rating    high_rate     low_rate
#        (int64)  (object)                                 (object)                 (object)    (object)               (object)    (float64)    (float64)       (object)    (float64)    (float64)
# --------------  ---------------------------------------  -----------------------  ----------  ----------------  -------------  -----------  -----------  -------------  -----------  -----------
#         269955  Hilton Garden Inn Albany/SUNY Area       1389 Washington Ave      Albany      NY                        12206      42.6875     -73.8164            3        154.027      124.022
#         113431  Courtyard by Marriott Albany Thruway     1455 Washington Avenue   Albany      NY                        12206      42.6897     -73.8202            3        179.01       134
# ...

# %%
from optimus.functions import F

# %%
# %%time
# a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
# c = 2 * np.arcsin(np.sqrt(a)) 

def haversine(lat1, lon1, lat2, lon2):    
    MILES = 3959
    lat1, lon1, lat2, lon2 = map(F.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1 
    dlon = lon2 - lon1     
    
    a = F.sin(dlat/2)**2 + F.cos(lat1) * F.cos(lat2) * F.sin(dlon/2)**2
    c = 2 * F.asin(F.sqrt(a))  
    total_miles = MILES * c
    return total_miles

df["distance"] = haversine(40.671, -73.985, df['latitude'], df['longitude'])
# Out:
# Wall time: 63 ms

# %%
(df.cols.select("distance"))
# Out:
#    distance
#   (float64)
# -----------
#     139.607
#     139.747
#     142.191
#     137.276
#     139.685
#     142.511
#     139.224
#     137.504
#     141.977

# %%
df
# Out:
#   ean_hotel_id  name                                     address1                 city        state_province      postal_code     latitude    longitude    star_rating    high_rate     low_rate
#        (int64)  (object)                                 (object)                 (object)    (object)               (object)    (float64)    (float64)       (object)    (float64)    (float64)
# --------------  ---------------------------------------  -----------------------  ----------  ----------------  -------------  -----------  -----------  -------------  -----------  -----------
#         269955  Hilton Garden Inn Albany/SUNY Area       1389 Washington Ave      Albany      NY                        12206      42.6875     -73.8164            3        154.027      124.022
#         113431  Courtyard by Marriott Albany Thruway     1455 Washington Avenue   Albany      NY                        12206      42.6897     -73.8202            3        179.01       134
# ...

# %%
def udf(df):
    return df["id"].cols.cos()+ df["id"].cols.sin()

udf(df)
# df.cols.assign({"a":udf})
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 4 of 4 rows / 1 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">id</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="0.8414709848078965">
#
# ...
